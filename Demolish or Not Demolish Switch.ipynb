# %%
import pandas as pd
import numpy as np

# %%
test = pd.read_csv('labour_accommodation_input.csv')
gfa_per_bed = 10
test['labour_beds_2022'] = test['labour_beds_2022'] * gfa_per_bed
test['labour_beds_2040'] = test['labour_beds_2040'] * gfa_per_bed
test['requirement'] = test['labour_beds_2040'] - test['labour_beds_2022']

# %%
labour_start = 2022
labour_end = 2040
plan_start = 2024
plan_end = 2040
plan_years=np.arange(plan_start,plan_end+1,1)

# %%
test_2 = test
test_2['growth_pa'] = test_2['requirement']/(labour_end-labour_start)
test_2 = test_2[test_2['growth_pa'] > 0]
test_2 = test_2[['ZONE','growth_pa']].reset_index(drop = True)

# %%
for year in plan_years:
    test_2[str(year)] = test_2['growth_pa']

test_2.head(5)
# Out:
#    ZONE    growth_pa         2024         2025         2026         2027  \
# 0   788    83.333333    83.333333    83.333333    83.333333    83.333333
# 1   791  1035.555556  1035.555556  1035.555556  1035.555556  1035.555556
# 2   792    21.666667    21.666667    21.666667    21.666667    21.666667
# 3   793   182.777778   182.777778   182.777778   182.777778   182.777778
# 4   796    37.222222    37.222222    37.222222    37.222222    37.222222
#
#           2028         2029         2030         2031         2032  \
# 0    83.333333    83.333333    83.333333    83.333333    83.333333
# 1  1035.555556  1035.555556  1035.555556  1035.555556  1035.555556
# 2    21.666667    21.666667    21.666667    21.666667    21.666667
# 3   182.777778   182.777778   182.777778   182.777778   182.777778
# 4    37.222222    37.222222    37.222222    37.222222    37.222222
#
#           2033         2034         2035         2036         2037  \
# ...
